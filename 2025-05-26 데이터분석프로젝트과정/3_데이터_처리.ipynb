# %%
import pandas as pd

df = {"Name": ["John", "Sarah", "Micheal"], "Age": [30, 25, 28], "Occupation": ["Engineer", "Doctor", "Teacher"]}
df = pd.DataFrame(df)
df.to_csv("./data.csv", index=False)

# %% [markdown]
# ## csv 모듈

# %%
import csv

with open("./data.csv", "r") as file:
    csv_reader = csv.reader(file)

    for row in csv_reader:
        print(row)
# Out:
# ['Name', 'Age', 'Occupation']
# ['John', '30', 'Engineer']
# ['Sarah', '25', 'Doctor']
# ['Micheal', '28', 'Teacher']

# %%
import pandas as pd

df = pd.read_csv("./data.csv")
print(df)
# Out:
#       Name  Age Occupation
# 0     John   30   Engineer
# 1    Sarah   25     Doctor
# 2  Micheal   28    Teacher

# %% [markdown]
# ## 데이터 변환

# %%
df['Adult'] = df['Age'] >= 18
print(df)
# Out:
#       Name  Age Occupation  Adult
# 0     John   30   Engineer   True
# 1    Sarah   25     Doctor   True
# 2  Micheal   28    Teacher   True

# %%
df['Birth(years)'] = 2025 - df['Age']
print(df)
# Out:
#       Name  Age Occupation  Adult  Birth(years)
# 0     John   30   Engineer   True          1995
# 1    Sarah   25     Doctor   True          2000
# 2  Micheal   28    Teacher   True          1997

# %%
import numpy as np

df['Adult'] = np.where(df['Adult']==True, 'adult', 'child')
df
# Out:
#       Name  Age Occupation  Adult  Birth(years)
# 0     John   30   Engineer  adult          1995
# 1    Sarah   25     Doctor  adult          2000
# 2  Micheal   28    Teacher  adult          1997

# %%
df = df.rename(columns={"Age": "Age(나이)"})
df
# Out:
#       Name  Age(나이) Occupation  Adult  Birth(years)
# 0     John       30   Engineer  adult          1995
# 1    Sarah       25     Doctor  adult          2000
# 2  Micheal       28    Teacher  adult          1997

# %%
df = df.rename(index={1:'one'})
df
# Out:
#         Name  Age(나이) Occupation  Adult  Birth(years)
# 0       John       30   Engineer  adult          1995
# one    Sarah       25     Doctor  adult          2000
# 2    Micheal       28    Teacher  adult          1997

# %%
filtered_df = df[df['Age(나이)']>=27]
print(filtered_df)

filtered_df2 = df[(df["Age(나이)"]>=27)&(df["Occupation"]=="Engineer")]
filtered_df2
# Out:
#       Name  Age(나이) Occupation  Adult  Birth(years)
# 0     John       30   Engineer  adult          1995
# 2  Micheal       28    Teacher  adult          1997
#    Name  Age(나이) Occupation  Adult  Birth(years)
# 0  John       30   Engineer  adult          1995

# %% [markdown]
# ### 퀴즈3, 실습1

# %% [markdown]
# ## 데이터 요약하기

# %%
import seaborn as sns

df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.describe(include='all')
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.shape
# Out:
# (891, 15)

# %%
print(df['survived'].value_counts())
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
print(df['pclass'].value_counts())
# Out:
# pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %% [markdown]
# ### 실습2

# %% [markdown]
# ## 이상치와 결측치

# %%
import seaborn as sns

df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import numpy as np
import matplotlib.pyplot as plt

sns.boxplot(y=df['age'])
plt.show()

# %%
Q1 = df['age'].quantile(q=0.25)
Q3 = df['age'].quantile(q=0.75)

IQR = Q3 - Q1
M = Q3 + 1.5 * IQR

print(M)
# Out:
# 64.8125

# %%
# 물론 나이 많은게 죄는 아니지만...
df[df['age']>64] = 64
sns.boxplot(y=df['age'])
plt.show()

# %%
print(df.notnull().sum())
print("-"*20)
print(df.isna().sum())
# Out:
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# alive          891
# alone          891
# dtype: int64
# --------------------
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df['age'] = df['age'].fillna(df['age'].mean())
print(df.isna().sum())
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
print(df['embark_town'].value_counts())
print(df['embarked'].value_counts())
# Out:
# embark_town
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64
# embarked
# S     638
# C     165
# Q      75
# 64     11
# Name: count, dtype: int64

# %%
df = df.drop(['embark_town'], axis=1)
print(df.columns)
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'alive', 'alone'],
#       dtype='object')

# %%
df = df.dropna()
print(df.isna().sum())
# Out:
# survived      0
# pclass        0
# sex           0
# age           0
# sibsp         0
# parch         0
# fare          0
# embarked      0
# class         0
# who           0
# adult_male    0
# deck          0
# alive         0
# alone         0
# dtype: int64

# %% [markdown]
# ### 실습3

# %% [markdown]
# ## 6. 데이터 병합

# %%
import pandas as pd

jul_df = {"날짜": ["2023-07-01", "2023-07-02"], "출금액": ["80,000", "1,500"], "입금액": ["0", "15,000"], "잔액": ["100,000", "250,000"]}
aug_df = {"날짜": ["2023-08-01", "2023-08-02"], "출금액": ["0", "3,000"], "입금액": ["15,000", "30,000"], "잔액": ["267,000", "310,000"]}

jul_df = pd.DataFrame(jul_df)
aug_df = pd.DataFrame(aug_df)

# %%
jul_aug_df = pd.concat([jul_df, aug_df]).reset_index(drop=True)
jul_aug_df.head()
# Out:
#            날짜     출금액     입금액       잔액
# 0  2023-07-01  80,000       0  100,000
# 1  2023-07-02   1,500  15,000  250,000
# 2  2023-08-01       0  15,000  267,000
# 3  2023-08-02   3,000  30,000  310,000

# %%
jul_aug_df = pd.concat([jul_df, aug_df], axis=1).reset_index(drop=True)
jul_aug_df.head()
# Out:
#            날짜     출금액     입금액       잔액          날짜    출금액     입금액       잔액
# 0  2023-07-01  80,000       0  100,000  2023-08-01      0  15,000  267,000
# 1  2023-07-02   1,500  15,000  250,000  2023-08-02  3,000  30,000  310,000

# %%
age_sex_df = {"이름": ["김철수", "최유리", "신짱구", "이훈이"], "나이": [32, 30, 29, 28], "성별": ["남", "여", "남", "남"]}
add_df = {"이름": ["김철수", "최유리", "정맹구"], "주소": ["안양시", "서울시", "인천시"]}
age_sex_df = pd.DataFrame(age_sex_df)
add_df = pd.DataFrame(add_df)

print(age_sex_df)
print(add_df)
# Out:
#     이름  나이 성별
# 0  김철수  32  남
# 1  최유리  30  여
# 2  신짱구  29  남
# 3  이훈이  28  남
#     이름   주소
# 0  김철수  안양시
# 1  최유리  서울시
# 2  정맹구  인천시

# %%
merge_data = pd.merge(age_sex_df, add_df, on="이름", how='inner')
merge_data
# Out:
#     이름  나이 성별   주소
# 0  김철수  32  남  안양시
# 1  최유리  30  여  서울시

# %%
merge_data = pd.merge(age_sex_df, add_df, on="이름", how='outer')
merge_data
# Out:
#     이름    나이   성별   주소
# 0  김철수  32.0    남  안양시
# 1  신짱구  29.0    남  NaN
# 2  이훈이  28.0    남  NaN
# 3  정맹구   NaN  NaN  인천시
# 4  최유리  30.0    여  서울시

# %%
merge_data = pd.merge(age_sex_df, add_df, on="이름", how='left')
merge_data
# Out:
#     이름  나이 성별   주소
# 0  김철수  32  남  안양시
# 1  최유리  30  여  서울시
# 2  신짱구  29  남  NaN
# 3  이훈이  28  남  NaN

# %%
merge_data = pd.merge(age_sex_df, add_df, on="이름", how='right')
merge_data
# Out:
#     이름    나이   성별   주소
# 0  김철수  32.0    남  안양시
# 1  최유리  30.0    여  서울시
# 2  정맹구   NaN  NaN  인천시

# %% [markdown]
# ### 실습4

# %% [markdown]
# ## 기초 통계

# %%
import seaborn as sns

df = sns.load_dataset('titanic')
print(df.mean(numeric_only=True))
# Out:
# survived       0.383838
# pclass         2.308642
# age           29.699118
# sibsp          0.523008
# parch          0.381594
# fare          32.204208
# adult_male     0.602694
# alone          0.602694
# dtype: float64

# %%
print(df.median(numeric_only=True))
# Out:
# survived       0.0000
# pclass         3.0000
# age           28.0000
# sibsp          0.0000
# parch          0.0000
# fare          14.4542
# adult_male     1.0000
# alone          1.0000
# dtype: float64

# %%
print(df.var(numeric_only=True))
# Out:
# survived         0.236772
# pclass           0.699015
# age            211.019125
# sibsp            1.216043
# parch            0.649728
# fare          2469.436846
# adult_male       0.239723
# alone            0.239723
# dtype: float64

# %%
print(df.std(numeric_only=True))
# Out:
# survived       0.486592
# pclass         0.836071
# age           14.526497
# sibsp          1.102743
# parch          0.806057
# fare          49.693429
# adult_male     0.489615
# alone          0.489615
# dtype: float64

# %% [markdown]
# ### 실습5

# %% [markdown]
# ## 미션1

# %%
import pandas as pd
import numpy as np


def drop_nan(df: pd.DataFrame) -> pd.DataFrame:
    "NaN값이 있는 행을 제거하여 반환합니다."

    df = None
    return df


def get_male_survived(df: pd.DataFrame) -> int:
    "남성 생존자의 수를 구하여 반환합니다."

    df_male_surv = None
    return len(df_male_surv)


def get_died_20(df: pd.DataFrame) -> int:
    "사망한 사람들 중 20 ~ 29살인 사람의 수를 구하여 반환합니다."

    died_20 = None
    return len(died_20)


def pclass1_survived_rate(df: pd.DataFrame) -> float:
    "Pclass가 1인 사람들의 생존자 비율을 반환합니다."

    None
    rate = None
    return rate


def main():
    DATA_PATH = "train.csv"

    # 데이터 불러오기
    df_train = pd.read_csv(DATA_PATH)
    print("전처리 전 데이터 수:", len(df_train))

    # 1. 결측치 제거하기
    df_train = drop_nan(df_train)
    print("전처리 후 데이터 수:", len(df_train))

    # 2. 남성 생존자수 구하기
    male_survived = get_male_survived(df_train)
    print("남성 생존자수:", male_survived)

    # 3. 20대 사망자수 구하기
    died_20 = get_died_20(df_train)
    print("20대 사망자수:", died_20)

    # 4. pclass 1의 생존자 비율 구하기
    survived_rate = pclass1_survived_rate(df_train)
    print("pclass 1의 생존자 비율:", survived_rate)


if __name__ == "__main__":
    main()
